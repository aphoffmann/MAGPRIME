# %% [markdown]
# ## Removing Stray Magnetic Fields from the KPLO Magnetometer Measurements
# Method Description
# 1. Interpolate to fill gaps
# 2. detrend with uniform filter (2 hours at least)
# 3. Run Ramen to find trend (Only works if mag offsets are calibrated fully and removed)
# 4. WAIC-UP

# %%
"Import Necessary Libraries"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fcwt

# %% [markdown]
# ## July 31st, 2023

# %%
"Load KMAG Data"
kmag = pd.read_csv(r'C:\Users\aphoffm2\Documents\GitHub\MAGPRIME\magprime\utility\SPACE_DATA\KPLO\KPLO_KMAG_230731_000000_RAW_M_01_one_second_average.csv')
B = kmag[['MAG1X','MAG1Y', 'MAG1Z','MAG2X', 'MAG2Y','MAG2Z', 'MAG3X','MAG3Y', 'MAG3Z']].to_numpy().T
B = B.reshape(3, 3, B.shape[-1])
t = pd.to_datetime(kmag['UTC']).to_numpy()

# %% [markdown]
# #### Fill Gaps

# %%
"Interpolate Gaps"
from magprime.utility import interpolation
interpolation.mssa.n_components = "parallel_analysis"
interpolation.mssa.pa_percentile_threshold = 95
interpolation.mssa.verbose = False

gaps = 1- np.isnan(B[0,0])
B_interpolated_x = interpolation.mssa.interpolate(np.copy(B[:,0]), np.copy(gaps), triaxial=False)
B_interpolated_y = interpolation.mssa.interpolate(np.copy(B[:,1]), np.copy(gaps), triaxial=False)
B_interpolated_z = interpolation.mssa.interpolate(np.copy(B[:,2]), np.copy(gaps), triaxial=False)
B_interpolated = np.stack((B_interpolated_x, B_interpolated_y, B_interpolated_z), axis=1)
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\pymssa\mssa.py:10: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 100%|██████████| 4/4 [00:00<00:00, 3998.38it/s]
# 100%|██████████| 4/4 [00:00<00:00, 3993.62it/s]
# 100%|██████████| 4/4 [00:00<00:00, 6209.18it/s]

# %% [markdown]
# ### RAMEN Algorithm

# %%
"Correct Low Frequency Offset"
from magprime.algorithms import RAMEN
from scipy.ndimage import uniform_filter1d
from importlib import reload
reload(RAMEN)

"Detrend"
sensors = np.copy(B_interpolated)
uf = int(7200) # Two Hours
trend = uniform_filter1d(sensors, size=uf)
sensors = sensors - trend

"Apply RAMEN"
RAMEN.flip = True
ramen_trend = RAMEN.clean(trend[:2]) # Only take trend from MAG-1 and MAG-2

"Plot Trend data"
plt.figure()
plt.plot(t, ramen_trend[0], label='X')
plt.plot(t, ramen_trend[1], label='Y')
plt.plot(t, ramen_trend[2], label='Z')
plt.legend()
plt.title('RAMEN Trend')
plt.show()
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\RAMEN.py:102: RuntimeWarning: invalid value encountered in divide
#   alpha_ij = np.nanmean(np.abs(B_filtered[0, axis]) / np.abs(B_filtered[i, axis]), axis=-1)

# %% [markdown]
# ### Remove Interference

# %%
"Apply WAIC-UP"
from magprime.algorithms import WAICUP


"Note: WAIC-UP is not designed to work with low-frequency data due to the Cone of Influence (COI). Detrending is necessary to avoid low-frequency artefacts."
WAICUP.fs = 1 # Sampling Frequency
WAICUP.detrend = False # Detrend the data

"Clean the data"
B_WAICUP = WAICUP.clean(np.copy(sensors), triaxial=True)
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\WAICUP.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   waicup_level1[i] = dual(np.vstack((sig[pairs[i][0]], sig[pairs[i][1]])), dt, dj)
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\WAICUP.py:42: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[axis] = cleanWAICUP(B[:,axis,:])

# %% [markdown]
# ### Plots and Data

# %%
"Find Correlation of WAIC-UP"
from scipy.stats import pearsonr
B_noise = sensors[2]-sensors[0]

correlation = [pearsonr(B_noise[i], B_WAICUP[i])[0] for i in range(3)]
print(correlation)

correlation = [pearsonr(B_noise[i], sensors[0,i])[0] for i in range(3)]
print(correlation)
# Out:
# [-0.41716905051915615, 0.18866747628747435, -0.3494164788188207]
# [-0.8479652002800827, 0.7163847954585779, -0.8705300233960923]

# %%
"Take Continuous Wavelet Transform"
fs = 1  # Hz
f0 = 0.0001 # Hz
f1 = 0.5  # Hz

# take transform of B_kplo Z-axis
freqs, out_kplo = fcwt.cwt(sensors[0,2], fs, f0, f1, fn=300, scaling='log', nthreads=12)
freqs = np.flip(freqs)

# take transform of WAICUP Z-axis
_, out_waicup = fcwt.cwt(B_WAICUP[2], fs, f0, f1, fn=300, scaling='log', nthreads=12)

# take transform of Interference Z-axis
_, out_noise = fcwt.cwt(sensors[2,2] - sensors[0,2], fs, f0, f1, fn=300, scaling='log', nthreads=12)

# Plot CWT
fig, axs = plt.subplots(1, 3, figsize=(15, 6))
extent_kplo = [0, out_kplo.shape[1], 0, out_kplo.shape[0]]
print(extent_kplo)
cax1 = axs[0].imshow(np.abs(out_kplo), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
cax2 = axs[1].imshow(np.abs(out_waicup), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
cax3 = axs[2].imshow(np.abs(out_noise), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
fig.colorbar(cax3, ax=axs[2], label='Logarithmic Magnitude')

yticks_kplo = np.linspace(0, len(freqs) - 1, 10).astype(int)
yticklabels_kplo = [f"{freqs[i]:.4f}" for i in yticks_kplo]

axs[0].set_yticks(yticks_kplo)
axs[0].set_yticklabels(yticklabels_kplo)
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('Frequency (Hz)')
axs[0].set_title("MAG1 Z-axis")

# TURN OFF YTICKS FOR AXS[1] AND AXS[2]
axs[1].set_yticks([])
axs[1].set_xlabel('Time (seconds)')
axs[1].set_title("WAIC-UP Z-axis")

axs[2].set_yticks([])
axs[2].set_xlabel('Time (seconds)')
axs[2].set_title("Interference Z-axis")
plt.tight_layout()
plt.show()
# Out:
# [0, 86400, 0, 300]

# %%
# Plot time series of B_waicup in 3 panel plot
fig, axs = plt.subplots(3, 1, figsize=(15, 15))
axs[0].plot(t, B[:,0].T, label=['MAG1X','MAG2X','MAG3X'])
axs[0].plot(t, B_WAICUP[0], label='Cleaned X-Axis')
#axs[0].set_ylim(-20,20)
axs[0].legend()
axs[1].plot(t, B[:,1].T, label=['MAG1Y','MAG2Y','MAG3Y'])
axs[1].plot(t, B_WAICUP[1], label='Cleaned Y-Axis')
#axs[1].set_ylim(-15,15)
axs[1].legend()
axs[2].plot(t, B[:,2].T, label=['MAG1Z','MAG2Z','MAG3Z'])
axs[2].plot(t, B_WAICUP[2], label='Cleaned Z-Axis')
axs[0].set_ylabel('Magnetic Field (nT)')
axs[1].set_ylabel('Magnetic Field (nT)')
axs[2].set_ylabel('Magnetic Field (nT)')
axs[2].set_xlabel('Time (UTC)')
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## May 4th, 2023

# %%
"Load KMAG Data"
kmag = pd.read_csv(r'C:\Users\aphoffm2\Documents\GitHub\MAGPRIME\magprime\utility\SPACE_DATA\KPLO\KPLO_KMAG_230504_000000_RAW_M_01_one_second_average.csv')
B_2 = kmag[['MAG1X','MAG1Y', 'MAG1Z','MAG2X', 'MAG2Y','MAG2Z', 'MAG3X','MAG3Y', 'MAG3Z']].to_numpy().T
B_2 = B_2.reshape(3, 3, B_2.shape[-1])
t_2 = pd.to_datetime(kmag['UTC']).to_numpy()

# %% [markdown]
# #### Fill Gaps

# %%
"Interpolate Gaps"
from magprime.utility import interpolation
interpolation.mssa.n_components = "parallel_analysis"
interpolation.mssa.pa_percentile_threshold = 95
interpolation.mssa.verbose = False

gaps = 1- np.isnan(B_2[0,0])
B_interpolated_x = interpolation.mssa.interpolate(np.copy(B_2[:,0]), np.copy(gaps), triaxial=False)
B_interpolated_y = interpolation.mssa.interpolate(np.copy(B_2[:,1]), np.copy(gaps), triaxial=False)
B_interpolated_z = interpolation.mssa.interpolate(np.copy(B_2[:,2]), np.copy(gaps), triaxial=False)
B_interpolated_2 = np.stack((B_interpolated_x, B_interpolated_y, B_interpolated_z), axis=1)
B_interpolated_2[np.isnan(B_interpolated_2)] = 0
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\pymssa\mssa.py:10: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 100%|██████████| 5/5 [00:00<00:00, 5008.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4997.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4535.36it/s]

# %% [markdown]
# #### RAMEN Algorithm

# %%
"Correct Low Frequency Offset"
from magprime.algorithms import RAMEN
from scipy.ndimage import uniform_filter1d
from importlib import reload
reload(RAMEN)

"Detrend"
sensors_2 = np.copy(B_interpolated_2)
uf = int(7200) # Two Hours
trend_2 = uniform_filter1d(sensors_2, size=uf)
sensors_2 = sensors_2 - trend_2

"Apply RAMEN"
ramen_trend_2 = RAMEN.clean(trend_2[:2]) # Only take trend from MAG-1 and MAG-2

"Plot Trend data"
plt.figure()
plt.plot(t_2, ramen_trend_2[0], label='X')
plt.plot(t_2, ramen_trend_2[1], label='Y')
plt.plot(t_2, ramen_trend_2[2], label='Z')
plt.legend()
plt.title('RAMEN Trend')
plt.show()
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\RAMEN.py:102: RuntimeWarning: invalid value encountered in divide
#   alpha_ij = np.nanmean(np.abs(B_filtered[0, axis]) / np.abs(B_filtered[i, axis]), axis=-1)

# %% [markdown]
# #### Remove Interference

# %%
"Apply WAIC-UP"
from magprime.algorithms import WAICUP


"Note: WAIC-UP is not designed to work with low-frequency data due to the Cone of Influence (COI). Detrending is necessary to avoid low-frequency artefacts."
WAICUP.fs = 1 # Sampling Frequency
WAICUP.detrend = False # Detrend the data

"Clean the data"
B_WAICUP_2 = WAICUP.clean(np.copy(sensors_2), triaxial=True)
# Out:
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\WAICUP.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   waicup_level1[i] = dual(np.vstack((sig[pairs[i][0]], sig[pairs[i][1]])), dt, dj)
# c:\Users\aphoffm2\AppData\Local\anaconda3\Lib\site-packages\magprime\algorithms\WAICUP.py:42: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[axis] = cleanWAICUP(B[:,axis,:])

# %% [markdown]
# #### Plots

# %%
"Find Correlation of WAIC-UP"
from scipy.stats import pearsonr
B_noise_2 = sensors_2[2]-sensors_2[0]

correlation = [pearsonr(B_noise_2[i], B_WAICUP_2[i] + ramen_trend_2[i])[0] for i in range(3)]
print(correlation)

correlation = [pearsonr(B_noise_2[i], sensors_2[0,i] + ramen_trend_2[i])[0] for i in range(3)]
print(correlation)
# Out:
# [-0.004712399389618618, -0.05722978242842561, 0.07505092203045816]
# [-0.20355255972742234, -0.1324445272684139, 0.18848162128464538]

# %%
"Take Continuous Wavelet Transform"
fs = 1  # Hz
f0 = 0.0001 # Hz
f1 = 0.5  # Hz

# take transform of B_kplo Z-axis
freqs, out_kplo = fcwt.cwt(sensors_2[0,2], fs, f0, f1, fn=300, scaling='log', nthreads=12)
freqs = np.flip(freqs)

# take transform of WAICUP Z-axis
_, out_waicup = fcwt.cwt(B_WAICUP_2[2], fs, f0, f1, fn=300, scaling='log', nthreads=12)

# take transform of Interference Z-axis
_, out_noise = fcwt.cwt(sensors_2[2,2] - sensors_2[0,2], fs, f0, f1, fn=300, scaling='log', nthreads=12)

# Plot CWT
fig, axs = plt.subplots(1, 3, figsize=(15, 6))
extent_kplo = [0, out_kplo.shape[1], 0, out_kplo.shape[0]]
print(extent_kplo)
cax1 = axs[0].imshow(np.abs(out_kplo), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
cax2 = axs[1].imshow(np.abs(out_waicup), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
cax3 = axs[2].imshow(np.abs(out_noise), aspect='auto', extent=extent_kplo, origin='upper', interpolation='none', cmap='Spectral_r', vmin=0, vmax=6)
fig.colorbar(cax3, ax=axs[2], label='Logarithmic Magnitude')

yticks_kplo = np.linspace(0, len(freqs) - 1, 10).astype(int)
yticklabels_kplo = [f"{freqs[i]:.4f}" for i in yticks_kplo]

axs[0].set_yticks(yticks_kplo)
axs[0].set_yticklabels(yticklabels_kplo)
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('Frequency (Hz)')
axs[0].set_title("MAG1 Z-axis")

# TURN OFF YTICKS FOR AXS[1] AND AXS[2]
axs[1].set_yticks([])
axs[1].set_xlabel('Time (seconds)')
axs[1].set_title("WAIC-UP Z-axis")

axs[2].set_yticks([])
axs[2].set_xlabel('Time (seconds)')
axs[2].set_title("Interference Z-axis")
plt.tight_layout()
plt.show()
# Out:
# [0, 86400, 0, 300]

# %%
# Plot time series of B_waicup in 3 panel plot
fig, axs = plt.subplots(3, 1, figsize=(15, 15))
axs[0].plot(t_2, B_2[:,0].T, label=['MAG1X','MAG2X','MAG3X'])
axs[0].plot(t_2, B_WAICUP_2[0]+ramen_trend_2[0], label='Cleaned X-Axis')
axs[0].legend()
axs[0].grid()
axs[1].plot(t_2, B_2[:,1].T, label=['MAG1Y','MAG2Y','MAG3Y'])
axs[1].plot(t_2, B_WAICUP_2[1]+ramen_trend_2[1], label='Cleaned Y-Axis')
axs[1].grid()
axs[1].legend()
axs[2].plot(t_2, B_2[:,2].T, label=['MAG1Z','MAG2Z','MAG3Z'])
axs[2].plot(t_2, B_WAICUP_2[2]+ramen_trend_2[2], label='Cleaned Z-Axis')

axs[0].set_ylabel('Magnetic Field (nT)')
axs[1].set_ylabel('Magnetic Field (nT)')
axs[2].set_ylabel('Magnetic Field (nT)')
axs[2].set_xlabel('Time (UTC)')
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()
